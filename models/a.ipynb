# %%
from tokenizer.regex import RegexTokenizer
tokenizer = RegexTokenizer()
text = open("../taylorswift.txt", "r", encoding="utf-8").read()
tokenizer.train(text, vocab_size=32)
tokenizer.encode("hello world") # string -> tokens
tokenizer.decode([1000, 2000, 3000]) # tokens -> string
tokenizer.save("tok32k") # writes tok32k.model and tok32k.vocab
tokenizer.load("tok32k.model") # loads the model back from disk
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from .tokenizer.regex import RegexTokenizer
#       2 tokenizer = RegexTokenizer()
#       3 text = open("../taylorswift.txt", "r", encoding="utf-8").read()
#
# ImportError: attempted relative import with no known parent package
